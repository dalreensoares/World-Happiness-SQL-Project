# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %% [markdown]
# # Data for top 5 and bottom 5 countries in 2021

# %%
# Data for top 5 and bottom 5 countries in 2021
data_2021 = {
    "Country": ["Finland", "Denmark", "Switzerland", "Iceland", "Netherlands", "Malawi", "Lesotho", "Botswana", "Rwanda", "Zimbabwe"],
    "Ladder_score": [7.842, 7.620, 7.571, 7.554, 7.464, 3.600, 3.512, 3.467, 3.415, 3.145],
    "Freedom_to_make_life_choices": [0.949, 0.946, 0.919, 0.955, 0.942, 0.380, 0.394, 0.422, 0.617, 0.345]
}

# Create DataFrame
df_2021 = pd.DataFrame(data_2021)

# Calculate the Pearson correlation coefficient
corr, p_value = pearsonr(df_2021["Freedom_to_make_life_choices"], df_2021["Ladder_score"])
print(f"Pearson correlation coefficient: {corr:.2f}")
print(f"P-value: {p_value:.2f}")

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Freedom_to_make_life_choices', y='Ladder_score', data=df_2021, hue='Country', s=100)
plt.title('Correlation between Freedom to make life choices and Ladder Score (2021)')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Ladder Score')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# Data for top 5 and bottom 5 countries in 2023
data_2023 = {
    "Country": ["Finland", "Denmark", "Iceland", "Israel", "Congo (Kinshasa)", "Zimbabwe", "Sierra Leone", "Lebanon", "Afghanistan"],
    "Ladder_score": [7.804, 7.586, 7.530, 7.473, 3.207, 3.204, 3.138, 2.392, 1.859],
    "Freedom_to_make_life_choices": [0.961, 0.934, 0.936, 0.809, 0.664, 0.654, 0.660, 0.474, 0.382]
}

# Create DataFrame
df_2023 = pd.DataFrame(data_2023)

# Calculate the Pearson correlation coefficient
corr, p_value = pearsonr(df_2023["Freedom_to_make_life_choices"], df_2023["Ladder_score"])
print(f"Pearson correlation coefficient: {corr:.2f}")
print(f"P-value: {p_value:.2f}")


# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Freedom_to_make_life_choices', y='Ladder_score', data=df_2023, hue='Country', s=100)
plt.title('Correlation between Freedom to make life choices and Ladder Score (2023)')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Ladder Score')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# Data for top 5 and bottom 5 countries in 2021
data_2021 = [
    {"Country": "Finland", "Ladder_score": 7.842, "Social_support": 0.954},
    {"Country": "Denmark", "Ladder_score": 7.62, "Social_support": 0.954},
    {"Country": "Switzerland", "Ladder_score": 7.571, "Social_support": 0.942},
    {"Country": "Iceland", "Ladder_score": 7.554, "Social_support": 0.955},
    {"Country": "Netherlands", "Ladder_score": 7.464, "Social_support": 0.941},
    {"Country": "Malawi", "Ladder_score": 3.6, "Social_support": 0.537},
    {"Country": "Lesotho", "Ladder_score": 3.512, "Social_support": 0.715},
    {"Country": "Botswana", "Ladder_score": 3.467, "Social_support": 0.824},
    {"Country": "Rwanda", "Ladder_score": 3.415, "Social_support": 0.897},
    {"Country": "Zimbabwe", "Ladder_score": 3.145, "Social_support": 0.677}
]

# Convert data to DataFrame
df_2021 = pd.DataFrame(data_2021)

# Calculate the Pearson correlation coefficient
corr, p_value = pearsonr(df_2021['Ladder_score'], df_2021['Social_support'])
print(f"Pearson correlation coefficient: {corr}")
print(f"P-value: {p_value}")

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Social_support', y='Ladder_score', data=df_2021, hue='Country', s=100)
plt.title('Correlation between Social Support and Ladder Score (2021)')
plt.xlabel('Social Support')
plt.ylabel('Ladder Score')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# Data for countries in 2023
data_2023 = {
    "Country": ["Finland", "Denmark", "Iceland", "Israel", "Congo (Kinshasa)", "Zimbabwe", "Sierra Leone", "Lebanon", "Afghanistan"],
    "Ladder_score": [7.804, 7.586, 7.530, 7.473, 3.207, 3.204, 3.138, 2.392, 1.859],
    "Social_support": [0.969, 0.954, 0.936, 0.943, 0.652, 0.690, 0.555, 0.530, 0.341]
}

# Create DataFrame
df_2023 = pd.DataFrame(data_2023)

# Calculate the Pearson correlation coefficient
corr, p_value = pearsonr(df_2023["Social_support"], df_2023["Ladder_score"])
print(f"Pearson correlation coefficient: {corr:.2f}")
print(f"P-value: {p_value:.2f}")


# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Social_support', y='Ladder_score', data=df_2023, hue='Country', s=100)
plt.title('Correlation between Social Support and Ladder Score (2023)')
plt.xlabel('Social Support')
plt.ylabel('Ladder Score')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# Data for countries in 2021
data_2021 = {
    "Country": ["Finland", "Denmark", "Switzerland", "Iceland", "Netherlands", "Lesotho", "Botswana", "Rwanda", "Zimbabwe", "Afghanistan"],
    "Ladder_score": [7.842, 7.620, 7.571, 7.554, 7.464, 3.512, 3.467, 3.415, 3.145, 2.523],
    "Logged_GDP_per_capita": [10.775, 10.933, 11.117, 10.878, 10.932, 7.926, 9.782, 7.676, 7.943, 7.695]
}

# Create DataFrame
df_2021 = pd.DataFrame(data_2021)

# Calculate the Pearson correlation coefficient
corr, p_value = pearsonr(df_2021["Logged_GDP_per_capita"], df_2021["Ladder_score"])
print(f"Pearson correlation coefficient: {corr:.2f}")
print(f"P-value: {p_value:.2f}")

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Logged_GDP_per_capita', y='Ladder_score', data=df_2021, hue='Country', s=100)
plt.title('Correlation between GDP and Ladder Score (2021)')
plt.xlabel('GDP')
plt.ylabel('Ladder Score')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# Data for countries in 2021
data_2023 = {
    "Country": ["Finland", "Denmark", "Iceland", "Switzerland", "Netherlands", "Congo (Kinshasa)", "Zimbabwe", "Sierra Leone", "Lebanon", "Afghanistan"],
    "Ladder_score": [7.842, 7.620, 7.571, 7.554, 7.464, 3.207, 3.204, 3.138, 2.392, 1.859],
    "Logged_GDP_per_capita": [10.775, 10.933, 11.117, 10.878, 10.942, 7.007, 7.641, 7.394, 9.478, 7.324]
}

# Create DataFrame
df_2023 = pd.DataFrame(data_2023)

# Calculate the Pearson correlation coefficient
corr, p_value = pearsonr(df_2023["Logged_GDP_per_capita"], df_2023["Ladder_score"])
print(f"Pearson correlation coefficient: {corr:.2f}")
print(f"P-value: {p_value:.2f}")

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Logged_GDP_per_capita', y='Ladder_score', data=df_2023, hue='Country', s=100)
plt.title('Correlation between GDP and Ladder Score (2023)')
plt.xlabel('GDP')
plt.ylabel('Ladder Score')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
